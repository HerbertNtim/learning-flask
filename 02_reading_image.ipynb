# %%
import numpy as np
import cv2
import matplotlib.image as matimg
from PIL import Image

import matplotlib.pyplot as plt

# %%
# OpencV BGR as numpy array
img_cv = cv2.imread('./data/flying_bird.jpg')
# Matplotlib RGB numpy array
img_mat = matimg.imread('./data/flying_bird.jpg')
# PIL - RGB numpy
img_pil = Image.open('./data/flying_bird.jpg')

# %%
# Out:
# array([[[ 21,  48,  92],
#         [ 19,  46,  90],
#         [ 16,  42,  88],
#         ...,
#         [  0,  14,  13],
#         [  0,  11,  10],
#         [  0,  15,  14]],
#
#        [[ 17,  44,  88],
#         [ 16,  43,  87],
#         [ 15,  41,  87],
#         ...,
#         [  4,  20,  19],
#         [  1,  17,  16],
#         [  0,  13,  12]],
#
#        [[ 19,  45,  91],
#         [ 19,  45,  91],
#         [ 19,  45,  92],
#         ...,
#         [  4,  22,  21],
#         [  7,  23,  22],
#         [  0,  15,  14]],
#
#        ...,
#
#        [[ 29,  57,  88],
#         [ 36,  64,  95],
#         [ 40,  65,  97],
#         ...,
#         [  1, 102,  77],
#         [  2,  98,  74],
#         [  1,  97,  73]],
#
#        [[ 36,  62,  92],
#         [ 38,  64,  94],
#         [ 39,  65,  95],
#         ...,
#         [  1, 102,  77],
#         [  3,  99,  75],
#         [  1,  97,  73]],
#
#        [[ 36,  62,  92],
#         [ 34,  60,  90],
#         [ 34,  60,  90],
#         ...,
#         [  0, 100,  75],
#         [  1,  97,  73],
#         [  1,  97,  73]]], shape=(480, 640, 3), dtype=uint8)
